# %% [markdown]
# <a href="https://colab.research.google.com/github/RoyJalil/RETOFINAL/blob/main/CODIGOFINALRETO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
df= pd.read_csv("Recolección de datos Negocios - IN 1002B  (Miércoles 22 de Noviembre 2023).csv", encoding= 'latin')
pd.options.display.max_columns = None
df.head(2)

# %%
df.info()

# %%
#Eliminar un signo de una columna
df['Equipo del entrevistador']=df['Equipo del entrevistador'].str.replace('Equipo ', '')
#Eliminar un signo de una columna
df['Equipo del entrevistador']=df['Equipo del entrevistador'].str.replace('Prueba ', '')
#Eliminar un signo de una columna
df['Equipo del entrevistador']=df['Equipo del entrevistador'].str.replace('EQUIPO ', '')
#Eliminar un signo de una columna
df['Equipo del entrevistador']=df['Equipo del entrevistador'].str.replace('N', '0')
#Eliminar un signo de una columna
df['Equipo del entrevistador']=df['Equipo del entrevistador'].str.replace('', '0')
#Eliminar un signo de una columna
df['Equipo del entrevistador']=df['Equipo del entrevistador'].str.replace('050 0', '0')
#Eliminar un signo de una columna
df['Equipo del entrevistador']=df['Equipo del entrevistador'].str.replace('030 0', '0')
#Eliminar un signo de una columna
df['Equipo del entrevistador']=df['Equipo del entrevistador'].str.replace('0e0q0u0i0p0o0 020 0', '0')
#Eliminar un signo de una columna
df['Equipo del entrevistador']=df['Equipo del entrevistador'].str.replace('0E0q0u0i0p0o030', '0')
#Eliminar un signo de una columna
df['Equipo del entrevistador']=df['Equipo del entrevistador'].str.replace('0G0', '0')
#Eliminar un signo de una columna
df['Equipo del entrevistador']=df['Equipo del entrevistador'].str.replace('010 0', '0')
#Eliminar un signo de una columna
df['Equipo del entrevistador']=df['Equipo del entrevistador'].str.replace('020 0', '0')
#Eliminar un signo de una columna
df['Equipo del entrevistador']=df['Equipo del entrevistador'].str.replace('0e0q0u0i0p0o0 020', '0')
#Eliminar un signo de una columna
df['Equipo del entrevistador']=df['Equipo del entrevistador'].str.replace('0e0q0u0i0p0o0 040', '0')
#Eliminar un signo de una columna
df['Equipo del entrevistador']=df['Equipo del entrevistador'].str.replace('Equipo ', '')
#Eliminar un signo de una columna
df['Equipo del entrevistador']=df['Equipo del entrevistador'].str.replace('Prueba ', '')
#Eliminar un signo de una columna
df['Equipo del entrevistador']=df['Equipo del entrevistador'].str.replace('EQUIPO ', '')
#Eliminar un signo de una columna
df['Equipo del entrevistador']=df['Equipo del entrevistador'].str.replace('Equipo', '')
#Eliminar un signo de una columna
df['Equipo del entrevistador']=df['Equipo del entrevistador'].str.replace('N', '0')
#Eliminar un signo de una columna
df['Equipo del entrevistador']=df['Equipo del entrevistador'].str.replace('equipo ', '')
#Eliminar un signo de una columna
df['Equipo del entrevistador']=df['Equipo del entrevistador'].str.replace('G', '0')

# %%
#Conversión de tipo de dato de columna de tipo Object a int
df['Equipo del entrevistador']= df['Equipo del entrevistador'].astype(int)

# %%
#Eliminar un signo de una columna
df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?']=df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?'].str.replace('3 sabores de helado fresa, vainilla y helado', '3')

# %%
#Eliminar un signo de una columna
df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?']=df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?'].str.replace('Diversos productos como golosinas, materia prima o artÃ\xadculos para fiestas', '0')

# %%
#Eliminar un signo de una columna
df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?']=df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?'].str.replace('Dulces, artÃ\xadculos de fiesta, materia prima.', '0')

# %%
df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?']=df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?'].str.replace('s', '0')

# %%
df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?']=df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?'].str.replace('Prueba 1', '0')

# %%
df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?']=df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?'].str.replace('No maneja produvto0', '0')

# %%
df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?']=df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?'].str.replace('Mucho0 no tiene el dato exacto ', '0')

# %%
df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?']=df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?'].str.replace('Ma0 de 20 producto0', '0')

# %%
df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?']=df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?'].str.replace('ni ifea', '0')

# %%
df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?']=df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?'].str.replace('Ma0 de 500', '0')

# %%
df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?']=df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?'].str.replace('8 y variedade0', '0')

# %%
df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?']=df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?'].str.replace('10 pretenda0 diaria0', '0')

# %%
df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?']=df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?'].str.replace('80-100', '0')

# %%
df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?']=df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?'].str.replace('3-4', '0')

# %%
df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?']=df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?'].str.replace('el menu', '0')

# %%
df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?']=df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?'].str.replace('Mucho0', '0')

# %%
#Conversión de tipo de dato de columna de tipo Object a int
df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?']= df['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?'].astype(int)

# %%
df.head(2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1166 entries, 0 to 1165
# Data columns (total 35 columns):
#  #   Column                                                                                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                   --------------  -----
#  0   Marca temporal                                                                                                                                                                           1166 non-null   object
#  1   Nombre del estudiante entrevistador                                                                                                                                                      1166 non-null   object
# ...

# %%
#Graficamos todas las dispersiones entre todas las variables
sns.pairplot(df)

# %%
filtro_numericos=df.iloc[ : , [4,11,12,13,31,32,34]]

# %%
sns.heatmap(filtro_numericos)

# %%
#Encontramos todas las correlaciones entre las variables
Corr_Factors=filtro_numericos.corr()
Corr_Factors
#Encontramos el valor absoluto de todas las correlaciones entre las variables
Corr_Factors1= abs(Corr_Factors)
Corr_Factors1

# %%
#Graficamos el mapa de calor de los coeficientes de correlación
Heat_Map= sns.heatmap(Corr_Factors1, cmap = 'coolwarm')
Heat_Map
# Out:
# <Axes: >

# %%
#Filtro por columnas
filtro10=df.iloc[ : , [8,10,11,12,13,15,16,19,21,22,23,24,25,32,34]]  #columnas no consecutivas,
filtro10

# %%
filtro10.info()

# %%
#Corroboramos valores nulos
valores_nulos=filtro10.isnull().sum()
valores_nulos
# Out:
# Tipo de negocio                                                                                                                                                                               0
# Antiguedad del negocio                                                                                                                                                                        0
# Â¿CuÃ¡ntos clientes, en promedio, recibe en un dÃ­a entre semana?                                                                                                                             0
# Â¿CuÃ¡ntos clientes, en promedio, recibe en un dÃ­a del fin de semana?                                                                                                                        0
# Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?                                                                                                                                     0
# ...

# %%
filtro10=filtro10.fillna(method="bfill")
filtro10=filtro10.fillna(method="ffill")
# Out:
# <ipython-input-44-cc67e182c863>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filtro10=filtro10.fillna(method="bfill")
# <ipython-input-44-cc67e182c863>:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filtro10=filtro10.fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=filtro10.isnull().sum()
valores_nulos
# Out:
# Tipo de negocio                                                                                                                                                                             0
# Antiguedad del negocio                                                                                                                                                                      0
# Â¿CuÃ¡ntos clientes, en promedio, recibe en un dÃ­a entre semana?                                                                                                                           0
# Â¿CuÃ¡ntos clientes, en promedio, recibe en un dÃ­a del fin de semana?                                                                                                                      0
# Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?                                                                                                                                   0
# ...

# %%
#Verificamos información del DataFrame
filtro10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1166 entries, 0 to 1165
# Data columns (total 15 columns):
#  #   Column                                                                                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                   --------------  -----
#  0   Tipo de negocio                                                                                                                                                                          1166 non-null   object
#  1   Antiguedad del negocio                                                                                                                                                                   1166 non-null   object
# ...

# %%
#Filtro para obtener variables cualitativas
Cualitativas=filtro10.iloc[ : , [0,1,5,6,7,8,9,10,11,12]]
Cualitativas

# %%
#Filtro para obtener variables cuantitativas
Cuantitativas=filtro10.iloc[ : , [2,3,4,13,14]]
Cuantitativas

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize =(15, 8))
Cuantitativas.plot(kind='box', vert=True)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=Cuantitativas

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido Â¿CuÃ¡ntos clientes, en promedio, recibe en un dÃ­a entre semana?                                85.000
# Â¿CuÃ¡ntos clientes, en promedio, recibe en un dÃ­a del fin de semana?                          112.625
# Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?                                       238.000
# En una escala de 1 a 10, Â¿cÃ³mo evaluarÃ­a sus esfuerzos para reducir su impacto ambiental?     12.500
# En una escala de 1 a 10, Â¿cÃ³mo evaluarÃ­a sus esfuerzos para reducir su impacto social?        12.500
# dtype: float64
# Limite inferior permitido Â¿CuÃ¡ntos clientes, en promedio, recibe en un dÃ­a entre semana?                               -35.000
# Â¿CuÃ¡ntos clientes, en promedio, recibe en un dÃ­a del fin de semana?                          -54.375
# Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?                                      -130.000
# ...

# %%
#Obtenemos datos limpios del Dataframe
Datos_sin_Outliers_iqr= Cuantitativas[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
Datos_sin_Outliers_iqr

# %%
#Corroboramos valores nulos
valores_nulos=Datos_sin_Outliers_iqr.isnull().sum()
valores_nulos
# Out:
# Â¿CuÃ¡ntos clientes, en promedio, recibe en un dÃ­a entre semana?                               129
# Â¿CuÃ¡ntos clientes, en promedio, recibe en un dÃ­a del fin de semana?                          109
# Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?                                       147
# En una escala de 1 a 10, Â¿cÃ³mo evaluarÃ­a sus esfuerzos para reducir su impacto ambiental?      0
# En una escala de 1 a 10, Â¿cÃ³mo evaluarÃ­a sus esfuerzos para reducir su impacto social?         0
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data_clean_iqr=Datos_sin_Outliers_iqr.copy()
data_clean_iqr=data_clean_iqr.fillna(round(Datos_sin_Outliers_iqr.mean(),1))
data_clean_iqr

# %%
#Corroboramos valores nulos
valores_nulos=data_clean_iqr.isnull().sum()
valores_nulos
# Out:
# Â¿CuÃ¡ntos clientes, en promedio, recibe en un dÃ­a entre semana?                               0
# Â¿CuÃ¡ntos clientes, en promedio, recibe en un dÃ­a del fin de semana?                          0
# Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?                                       0
# En una escala de 1 a 10, Â¿cÃ³mo evaluarÃ­a sus esfuerzos para reducir su impacto ambiental?    0
# En una escala de 1 a 10, Â¿cÃ³mo evaluarÃ­a sus esfuerzos para reducir su impacto social?       0
# dtype: int64

# %%
Dataframe_final_reto = pd.concat([Cualitativas, data_clean_iqr], axis=1)
Dataframe_final_reto

# %%
Dataframe_final_reto.head(2)

# %%
Dataframe_final_reto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1166 entries, 0 to 1165
# Data columns (total 15 columns):
#  #   Column                                                                                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                   --------------  -----
#  0   Tipo de negocio                                                                                                                                                                          1166 non-null   object
#  1   Antiguedad del negocio                                                                                                                                                                   1166 non-null   object
# ...

# %%
freq_tbl(Dataframe_final_reto)

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Dataframe_final_reto['Tipo de negocio'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>25]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('Tipo de negocio')
Filtro_index1
#Realizamos grafico de barras del dataframe filtrado
Filtro_index1.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Herramientas de relación con los clientes')
plt.xlabel('Tipo de Herramienta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Dataframe_final_reto['Antiguedad del negocio'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('Antiguedad del negocio')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True,autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Dataframe_final_reto['Â¿QuÃ© forma de pago permite a sus clientes?'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>25]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('Â¿QuÃ© forma de pago permite a sus clientes?')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Dataframe_final_reto['En los Ãºltimos seis meses Â¿ha implementado alguna tecnologÃ­a digital en su negocio?'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('En los Ãºltimos seis meses Â¿ha implementado alguna tecnologÃ­a digital en su negocio?')
Filtro_index1
#Realizamos grafico de barras del dataframe filtrado
Filtro_index1.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Herramientas de relación con los clientes')
plt.xlabel('Tipo de Herramienta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Dataframe_final_reto['Â¿QuÃ© factores influyeron o influirÃ­an en su decisiÃ³n de adoptar tecnologÃ­a en su tienda? (Seleccione todos los que procedan)'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>25]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('Â¿QuÃ© factores influyeron o influirÃ­an en su decisiÃ³n de adoptar tecnologÃ­a en su tienda? (Seleccione todos los que procedan)')
Filtro_index1
#Realizamos grafico de barras del dataframe filtrado
Filtro_index1.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Herramientas de relación con los clientes')
plt.xlabel('Tipo de Herramienta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Dataframe_final_reto['Â¿A travÃ©s de cuÃ¡les de los siguientes medios se comunicas con los proveedores?'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>25]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('Â¿A travÃ©s de cuÃ¡les de los siguientes medios se comunicas con los proveedores?')
Filtro_index1
#Realizamos grafico de barras del dataframe filtrado
Filtro_index1.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Herramientas de relación con los clientes')
plt.xlabel('Tipo de Herramienta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Dataframe_final_reto['Â¿A travÃ©s de cuÃ¡les de los siguientes medios recibes pedidos de los clientes?'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>25]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('Â¿A travÃ©s de cuÃ¡les de los siguientes medios recibes pedidos de los clientes?')
Filtro_index1
#Realizamos grafico de barras del dataframe filtrado
Filtro_index1.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Herramientas de relación con los clientes')
plt.xlabel('Tipo de Herramienta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Dataframe_final_reto["Â¿CuÃ¡l es su grado de satisfacciÃ³n con las soluciones tecnolÃ³gicas que ha implantado en su tienda?"])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('Â¿CuÃ¡l es su grado de satisfacciÃ³n con las soluciones tecnolÃ³gicas que ha implantado en su tienda?')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
Dataframe_final_reto.info()

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df[['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?']]
Var_Dep= df['En una escala de 1 a 10, Â¿cÃ³mo evaluarÃ­a sus esfuerzos para reducir su impacto ambiental?']
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__

# %% [markdown]
# **MODELO 1: No. PRODUCTOS VS IMPACTO AMBIENTAL y=--5.30615406e-05x + 6.676167493806014**

# %%
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# ...

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.06693151708350578

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
sns.scatterplot(x='Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?', y='En una escala de 1 a 10, Â¿cÃ³mo evaluarÃ­a sus esfuerzos para reducir su impacto ambiental?', color="blue", data=df)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?', ylabel='En una escala de 1 a 10, Â¿cÃ³mo evaluarÃ\xada sus esfuerzos para reducir su impacto ambiental?'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df[['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?']]
Var_Dep= df['Â¿CuÃ¡ntos clientes, en promedio, recibe en un dÃ­a entre semana?']
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__

# %% [markdown]
# **Modelo Lineal 2 NO. PRODUCTOS VS CLIENTES ENTRE SEMANA : y=0.00064448x+ 41.56232349347227**

# %%
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# ...

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.027706000827707068

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
sns.scatterplot(x='Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?', y='Â¿CuÃ¡ntos clientes, en promedio, recibe en un dÃ­a entre semana?', color="blue", data=df)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?', ylabel='Â¿CuÃ¡ntos clientes, en promedio, recibe en un dÃ\xada entre semana?'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df[['Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?']]
Var_Dep= df['Â¿CuÃ¡ntos clientes, en promedio, recibe en un dÃ­a del fin de semana?']
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__

# %% [markdown]
# **Modelo Matemático 3 PRODUCTOS VS CLIENTES EN FIN: y= 0.00036257x + 50.620807029795586**

# %%
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# ...

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.01093499288982266

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
sns.scatterplot(x='Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?', y='Â¿CuÃ¡ntos clientes, en promedio, recibe en un dÃ­a del fin de semana?', color="blue", data=df)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?', ylabel='Â¿CuÃ¡ntos clientes, en promedio, recibe en un dÃ\xada del fin de semana?'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df[['En una escala de 1 a 10, Â¿cÃ³mo evaluarÃ­a sus esfuerzos para reducir su impacto ambiental?']]
Var_Dep= df['En una escala de 1 a 10, Â¿cÃ³mo evaluarÃ­a sus esfuerzos para reducir su impacto social?']
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
y_pred= model.predict(X=df[['En una escala de 1 a 10, Â¿cÃ³mo evaluarÃ­a sus esfuerzos para reducir su impacto ambiental?']])
y_pred
y_pred= model.predict(X=df[['En una escala de 1 a 10, Â¿cÃ³mo evaluarÃ­a sus esfuerzos para reducir su impacto ambiental?']])
y_pred

# %% [markdown]
# **MODELO FINAL: 0.5927815x + 2.8261348828399533**

# %%
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# ...

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.5645999542724242

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
sns.scatterplot(x='Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?', y='Â¿CuÃ¡ntos clientes, en promedio, recibe en un dÃ­a del fin de semana?', color="blue", data=df)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Â¿CuÃ¡ntos productos aproximadamente maneja en su tienda?', ylabel='Â¿CuÃ¡ntos clientes, en promedio, recibe en un dÃ\xada del fin de semana?'>

# %%
Dataframe_final_reto.head(2)
# Out:
#    Predicciones Tipo de negocio   Antiguedad del negocio  \
# 0      6.975605          Prueba        Entre 0 y 6 meses
# 1      6.975605     HeladerÃ­a   Entre 6 meses y un aÃ±o
#
#   Â¿QuÃ© forma de pago permite a sus clientes?  \
# 0                                     Efectivo
# 1                                     Efectivo
#
#   Â¿Ha participado en algÃºn plan de colaboraciÃ³n con otras tiendas o empresas? \n(por ejemplo, esfuerzos conjuntos de marketing, compras al por mayor, servicios de entrega compartidos)  \
# 0                                                SÃ­
# 1                                                 No
#
#   En los Ãºltimos seis meses Â¿ha implementado alguna tecnologÃ­a digital en su negocio?  \
# 0                                                 No
# 1                                                 No
#
#   Â¿QuÃ© factores influyeron o influirÃ­an en su decisiÃ³n de adoptar tecnologÃ­a en su tienda? (Seleccione todos los que procedan)  \
# ...

# %%
#Convertir archivo a CSV
Dataframe_final_reto.to_csv("Base de datos final.csv")

# %%
from google.colab import files


files.download("Base de datos final.csv")
